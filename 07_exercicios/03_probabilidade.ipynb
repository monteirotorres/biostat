# %% [markdown]
# # Exercícios — Probabilidade

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# ## Exercício 1 — Chevalier de Méré

# %%
print('ao menos um 6 em 4 jogadas:', round(1-(5/6)**4, 4))
print('ao menos um duplo-6 em 24:', round(1-(35/36)**24, 4))

# %% [markdown]
# ## Exercício 2 — Megasena

# %%
from math import comb
print('P =', 1/comb(60,6))

# %% [markdown]
# ## Exercício 3 — Falso positivo na publicação

# %%
print('independente:', 0.05*0.05)
print('dependente:', 0.05*0.30)
