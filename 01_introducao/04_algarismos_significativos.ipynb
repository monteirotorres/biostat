# %% [markdown]
# # Algarismos significativos
#
# Vamos ver como o Python lida com arredondamento.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set_theme(style="whitegrid")

# %%
valor = 3.14159265
round(valor, 2), round(valor, 4)

# %% [markdown]
# ## Em DataFrames

# %%
df = pd.DataFrame({'altura': [1.6234, 1.7567, 1.8123],
                   'peso':   [62.34,  75.671, 81.123]})
df.round({'altura': 2, 'peso': 1})

# %% [markdown]
# ## Formatando para exibição

# %%
for v in [12345.678, 0.000045678, 3.14]:
    print(f'{v:.3g}')
